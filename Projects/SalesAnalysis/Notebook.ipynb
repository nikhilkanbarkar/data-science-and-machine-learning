# %% [markdown]
# # Sales Analysis

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# importing DataFrame
sales_df = pd.read_csv("D:/Artificial intelligence/conda project/datasets/Sales_data.csv", encoding="latin1")
sales_df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ## Data Exploration

# %%
sales_df.info
# Out:
# <bound method DataFrame.info of       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
sales_df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
sales_df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='str')

# %%
len(sales_df)
# Out:
# 9994

# %%
sales_df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
sales_df.dtypes
# Out:
# Row ID             int64
# Order ID             str
# Order Date           str
# Ship Date            str
# Ship Mode            str
# Customer ID          str
# Customer Name        str
# Segment              str
# Country              str
# City                 str
# State                str
# Postal Code        int64
# Region               str
# Product ID           str
# Category             str
# Sub-Category         str
# Product Name         str
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %% [markdown]
# ## Data cleaning and future engineering

# %%
sales_df.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 6       7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 7       8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 8       9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 9      10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %%
# few columns are optional so we can clean it
sales_df = sales_df.drop("Row ID",axis=1)
sales_df = sales_df.drop("Postal Code",axis=1)

# %%
sales_df = sales_df.drop("Country",axis=1)

# %%
sales_df
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1     CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2     CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4     US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9989  CA-2014-110422   1/21/2014   1/23/2014    Second Class    TB-21400
# 9990  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class    DB-13060
# 9993  CA-2017-119914    5/4/2017    5/9/2017    Second Class    CC-12220
#
#          Customer Name    Segment             City       State Region  \
# ...

# %%
sales_df["Order Date"] = pd.to_datetime(sales_df["Order Date"])
sales_df["Ship Date"] = pd.to_datetime(sales_df["Ship Date"])

# Shipping days
sales_df["Shipping Days"] = (sales_df["Ship Date"] - sales_df["Order Date"])

# %%
# Order Month and Year for calculating sales 
sales_df["Month"] = sales_df["Order Date"].dt.month_name()
sales_df["Year"] = sales_df["Order Date"].dt.year
sales_df["Weekday"] = sales_df["Order Date"].dt.day_name()

# %%
sales_df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2     CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# ...              ...        ...        ...             ...         ...
# 9989  CA-2014-110422 2014-01-21 2014-01-23    Second Class    TB-21400
# 9990  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9993  CA-2017-119914 2017-05-04 2017-05-09    Second Class    CC-12220
#
#          Customer Name    Segment             City       State Region  ...  \
# ...

# %% [markdown]
# In the Superstore dataset:<br>
# <br>
#
# Sales = Total amount after discount<br>
# Quantity = Number of units sold<br>
# Discount = Discount rate (e.g., 0.20 = 20%)<br>
# Profit = Profit earned on the sale<br>

# %%
sales_df["Selling Price"] = sales_df["Sales"] / sales_df["Quantity"]

sales_df["Original Price"] = (
    sales_df["Sales"] / (1 - sales_df["Discount"])
) / sales_df["Quantity"]

sales_df["Discount Amount"] = (
    sales_df["Original Price"] * sales_df["Quantity"]
) - sales_df["Sales"]

# %%
sales_df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'City', 'State', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping Days', 'Month', 'Year', 'Weekday',
#        'Selling Price', 'Original Price', 'Discount Amount'],
#       dtype='str')

# %%
# lets Re-arrange the columns in structured way.

sales_df = sales_df[
    [
        # Order Information
        "Order ID",
        "Order Date",
        "Ship Date",
        "Shipping Days",
        "Ship Mode",

        # Customer Information
        "Customer ID",
        "Customer Name",
        "Segment",

        # Location Information
        "City",
        "State",
        "Region",

        # Product Information
        "Product ID",
        "Category",
        "Sub-Category",
        "Product Name",

        # Sales Information
        "Quantity",
        "Original Price",
        "Discount",
        "Discount Amount",
        "Selling Price",
        "Sales",
        "Profit",

        # Time Features
        "Month",
        "Year",
        "Weekday"
    ]
]

# %%
sales_df
# Out:
#             Order ID Order Date  Ship Date Shipping Days       Ship Mode  \
# 0     CA-2016-152156 2016-11-08 2016-11-11        3 days    Second Class
# 1     CA-2016-152156 2016-11-08 2016-11-11        3 days    Second Class
# 2     CA-2016-138688 2016-06-12 2016-06-16        4 days    Second Class
# 3     US-2015-108966 2015-10-11 2015-10-18        7 days  Standard Class
# 4     US-2015-108966 2015-10-11 2015-10-18        7 days  Standard Class
# ...              ...        ...        ...           ...             ...
# 9989  CA-2014-110422 2014-01-21 2014-01-23        2 days    Second Class
# 9990  CA-2017-121258 2017-02-26 2017-03-03        5 days  Standard Class
# 9991  CA-2017-121258 2017-02-26 2017-03-03        5 days  Standard Class
# 9992  CA-2017-121258 2017-02-26 2017-03-03        5 days  Standard Class
# 9993  CA-2017-119914 2017-05-04 2017-05-09        5 days    Second Class
#
#      Customer ID     Customer Name    Segment             City       State  \
# ...

# %%
sales_df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Shipping Days', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Region',
#        'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Quantity',
#        'Original Price', 'Discount', 'Discount Amount', 'Selling Price',
#        'Sales', 'Profit', 'Month', 'Year', 'Weekday'],
#       dtype='str')

# %% [markdown]
# ## <b>ANALYSIS</b>

# %% [markdown]
# ### Overall Sales

# %%
total_sales = sales_df["Sales"].sum()
total_sales
# Out:
# np.float64(2297200.8603)

# %%
total_profit = sales_df["Profit"].sum()
total_profit
# Out:
# np.float64(286397.0217)

# %% [markdown]
# <b>Total Orders</b><br>
#
# Count the total number of unique orders placed.</br>
#
# Since one order can contain multiple products, use unique Order IDs.</br>

# %%
total_orders = sales_df["Order ID"].nunique()
total_orders
# Out:
# 5009

# %%
total_quantity_sold = sales_df["Quantity"].sum()
total_quantity_sold
# Out:
# np.int64(37873)

# %%
average_sales = sales_df["Sales"].mean()
average_sales
# Out:
# np.float64(229.85800083049827)

# %%
average_profit = sales_df["Profit"].mean()
average_profit
# Out:
# np.float64(28.65689630778467)

# %%
print("=" * 45)
print("        OVERALL SALES ANALYSIS")
print("=" * 45)

print(f"Total Sales         :${total_sales:,.2f}")
print(f"Total Profit        : ${total_profit:,.2f}")
print(f"Total Orders        : {total_orders:,}")
print(f"Total Quantity Sold : {total_quantity_sold:,}")
print(f"Average Sales       : ${average_sales:,.2f}")
print(f"Average Profit      : ${average_profit:,.2f}")

print("=" * 45)
# Out:
# ...
#         OVERALL SALES ANALYSIS
# ...
# Total Sales         :$2,297,200.86
# Total Profit        : $286,397.02
# Total Orders        : 5,009
# Total Quantity Sold : 37,873
# Average Sales       : $229.86
# Average Profit      : $28.66
# ...

# %% [markdown]
# ### Product Analysis

# %%
sales_df
# Out:
#             Order ID Order Date  Ship Date Shipping Days       Ship Mode  \
# 0     CA-2016-152156 2016-11-08 2016-11-11        3 days    Second Class
# 1     CA-2016-152156 2016-11-08 2016-11-11        3 days    Second Class
# 2     CA-2016-138688 2016-06-12 2016-06-16        4 days    Second Class
# 3     US-2015-108966 2015-10-11 2015-10-18        7 days  Standard Class
# 4     US-2015-108966 2015-10-11 2015-10-18        7 days  Standard Class
# ...              ...        ...        ...           ...             ...
# 9989  CA-2014-110422 2014-01-21 2014-01-23        2 days    Second Class
# 9990  CA-2017-121258 2017-02-26 2017-03-03        5 days  Standard Class
# 9991  CA-2017-121258 2017-02-26 2017-03-03        5 days  Standard Class
# 9992  CA-2017-121258 2017-02-26 2017-03-03        5 days  Standard Class
# 9993  CA-2017-119914 2017-05-04 2017-05-09        5 days    Second Class
#
#      Customer ID     Customer Name    Segment             City       State  \
# ...

# %% [markdown]
# <b> Best selling by Quantity

# %%
best_selling = (
    sales_df.groupby("Product Name")["Quantity"]
      .sum()
      .sort_values(ascending=False)
)

print(best_selling.head(10))
# Out:
# Product Name
# Staples                                                       215
# Staple envelope                                               170
# Easy-staple paper                                             150
# Staples in misc. colors                                        86
# KI Adjustable-Height Table                                     74
# Storex Dura Pro Binders                                        71
# Avery Non-Stick Binders                                        71
# GBC Premium Transparent Covers with Diagonal Lined Pattern     67
# Situations Contoured Folding Chairs, 4/Set                     64
# Staple-based wall hangings                                     62
# Name: Quantity, dtype: int64

# %%
lowest_selling = (
    sales_df.groupby("Product Name")["Quantity"]
            .sum()
            .sort_values()
)
lowest_selling.head(20)
# Out:
# Product Name
# Penpower WorldCard Pro Card Scanner                                                    1
# Global Enterprise Series Seating Low-Back Swivel/Tilt Chairs                           1
# Bush Saratoga Collection 5-Shelf Bookcase, Hanover Cherry, *Special Order              1
# Boston 1900 Electric Pencil Sharpener                                                  1
# Xerox 20                                                                               1
# Grip Seal Envelopes                                                                    2
# Eureka Disposable Bags for Sanitaire Vibra Groomer I Upright Vac                       2
# Xerox 1984                                                                             2
# Avery Hi-Liter Pen Style Six-Color Fluorescent Set                                     2
# PNY Rapid USB Car Charger - Black                                                      2
# ...

# %% [markdown]
# <b>most profitable & least profitable </b>

# %%
most_profitable = (sales_df.groupby("Product Name")["Profit"]
    .sum()
    .sort_values(ascending = False)
)
most_profitable
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          25199.9280
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind     7753.0390
# Hewlett Packard LaserJet 3310 Copier                                            6983.8836
# Canon PC1060 Personal Laser Copier                                              4570.9347
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                       4094.9766
#                                                                                   ...
# Bush Advantage Collection Racetrack Conference Table                           -1934.3976
# Chromcraft Bull-Nose Wood Oval Conference Tables & Bases                       -2876.1156
# Cubify CubeX 3D Printer Triple Head Print                                      -3839.9904
# Lexmark MX611dhe Monochrome Laser Printer                                      -4589.9730
# ...

# %%
least_profitable = (
    sales_df.groupby("Product Name")["Profit"]
            .sum()
            .sort_values()
)
least_profitable.head(20)
# Out:
# Product Name
# Cubify CubeX 3D Printer Double Head Print                                      -8879.9704
# Lexmark MX611dhe Monochrome Laser Printer                                      -4589.9730
# Cubify CubeX 3D Printer Triple Head Print                                      -3839.9904
# Chromcraft Bull-Nose Wood Oval Conference Tables & Bases                       -2876.1156
# Bush Advantage Collection Racetrack Conference Table                           -1934.3976
# GBC DocuBind P400 Electric Binding System                                      -1878.1662
# Cisco TelePresence System EX90 Videoconferencing Unit                          -1811.0784
# Martin Yale Chadless Opener Electric Letter Opener                             -1299.1836
# Balt Solid Wood Round Tables                                                   -1201.0581
# BoxOffice By Design Rectangular and Half-Moon Meeting Room Tables              -1148.4375
# ...

# %% [markdown]
# <b>"Top 10 Selling Products By sales

# %%
top_product = (sales_df.groupby("Product Name")["Sales"]
                           .sum()
                           .sort_values(ascending=False)
                  )
top_product
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
#                                                                                  ...
# Avery Hi-Liter Pen Style Six-Color Fluorescent Set                                 7.700
# Grip Seal Envelopes                                                                7.072
# Xerox 20                                                                           6.480
# Avery 5                                                                            5.760
# ...

# %%
low_product = (sales_df.groupby("Product Name")["Sales"]
                           .sum()
                           .sort_values()
                  )
low_product
# Out:
# Product Name
# Eureka Disposable Bags for Sanitaire Vibra Groomer I Upright Vac                   1.624
# Avery 5                                                                            5.760
# Xerox 20                                                                           6.480
# Grip Seal Envelopes                                                                7.072
# Avery Hi-Liter Pen Style Six-Color Fluorescent Set                                 7.700
#                                                                                  ...
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# ...

# %%
highest_discount = (
    sales_df.groupby("Product Name")["Discount"]
      .mean()
      .sort_values(ascending=False)
)
highest_discount
# Out:
# Product Name
# Eureka Disposable Bags for Sanitaire Vibra Groomer I Upright Vac    0.800000
# GBC Plasticlear Binding Covers                                      0.728571
# GBC VeloBinder Electric Binding Machine                             0.725000
# Epson Perfection V600 Photo Scanner                                 0.700000
# Lexmark MarkNet N8150 Wireless Print Server                         0.700000
#                                                                       ...
# Xerox 1969                                                          0.000000
# Eldon 200 Class Desk Accessories, Smoke                             0.000000
# Eldon 200 Class Desk Accessories, Black                             0.000000
# Zebra ZM400 Thermal Label Printer                                   0.000000
# Xiaomi Mi3                                                          0.000000
# Name: Discount, Length: 1850, dtype: float64

# %%
top_product.head(20).plot(kind="barh", figsize=(10,6))
# Out:
# <Axes: ylabel='Product Name'>

# %% [markdown]
# ### Category Analysis
# This analysis answers:<br>
#
# Which category generates the highest sales?<br>
# Which category generates the highest profit?<br>
# Which category sells the highest quantity?

# %%
category_sales = (
    sales_df.groupby("Category")["Sales"]
            .sum()
            .sort_values(ascending=False)
)

category_sales
# Out:
# Category
# Technology         836154.0330
# Furniture          741999.7953
# Office Supplies    719047.0320
# Name: Sales, dtype: float64

# %%
category_profit = (
    sales_df.groupby("Category")["Profit"]
            .sum()
            .sort_values(ascending=False)
)

category_profit
# Out:
# Category
# Technology         145454.9481
# Office Supplies    122490.8008
# Furniture           18451.2728
# Name: Profit, dtype: float64

# %%
category_quantity = (
    sales_df.groupby("Category")["Quantity"]
            .sum()
            .sort_values(ascending=False)
)

category_quantity
# Out:
# Category
# Office Supplies    22906
# Furniture           8028
# Technology          6939
# Name: Quantity, dtype: int64

# %%
category_sales.plot(
    kind="bar",
    figsize=(8,5),
    title="Sales by Category"
)
# Out:
# <Axes: title={'center': 'Sales by Category'}, xlabel='Category'>

# %%
category_profit.plot(
    kind="bar",
    figsize=(8,5),
    title="Profit by Category"
)
# Out:
# <Axes: title={'center': 'Profit by Category'}, xlabel='Category'>

# %%
category_quantity.plot(
    kind="bar",
    figsize=(8,5),
    title="Quantity by Category"
)
# Out:
# <Axes: title={'center': 'Quantity by Category'}, xlabel='Category'>

# %% [markdown]
# #### Sub-Category Analysis

# %%
highest_sales_subcategory = (
    sales_df.groupby("Sub-Category")["Sales"]
            .sum()
            .sort_values(ascending=False)
)

print(highest_sales_subcategory)
# Out:
# Sub-Category
# Phones         330007.0540
# Chairs         328449.1030
# Storage        223843.6080
# Tables         206965.5320
# Binders        203412.7330
# Machines       189238.6310
# Accessories    167380.3180
# Copiers        149528.0300
# Bookcases      114879.9963
# Appliances     107532.1610
# Furnishings     91705.1640
# Paper           78479.2060
# Supplies        46673.5380
# Art             27118.7920
# Envelopes       16476.4020
# Labels          12486.3120
# Fasteners        3024.2800
# Name: Sales, dtype: float64

# %%
highest_sales_subcategory.plot(
    kind="barh",
    figsize=(10,6),
    title="Sales by Sub-Category"
)
# Out:
# <Axes: title={'center': 'Sales by Sub-Category'}, ylabel='Sub-Category'>

# %%
lowest_profit_subcategory = (
    sales_df.groupby("Sub-Category")["Profit"]
            .sum()
            .sort_values()
)

print(lowest_profit_subcategory)
# Out:
# Sub-Category
# Tables        -17725.4811
# Bookcases      -3472.5560
# Supplies       -1189.0995
# Fasteners        949.5182
# Machines        3384.7569
# Labels          5546.2540
# Art             6527.7870
# Envelopes       6964.1767
# Furnishings    13059.1436
# Appliances     18138.0054
# Storage        21278.8264
# Chairs         26590.1663
# Binders        30221.7633
# Paper          34053.5693
# Accessories    41936.6357
# Phones         44515.7306
# Copiers        55617.8249
# Name: Profit, dtype: float64

# %%
lowest_profit_subcategory.plot(
    kind="barh",
    figsize=(10,6),
    title="Profit by Sub-Category"
)
# Out:
# <Axes: title={'center': 'Profit by Sub-Category'}, ylabel='Sub-Category'>

# %%
highest_discount_subcategory = (
    sales_df.groupby("Sub-Category")["Discount"]
            .mean()
            .sort_values(ascending=False)
)

print(highest_discount_subcategory)
# Out:
# Sub-Category
# Binders        0.372292
# Machines       0.306087
# Tables         0.261285
# Bookcases      0.211140
# Chairs         0.170178
# Appliances     0.166524
# Copiers        0.161765
# Phones         0.154556
# Furnishings    0.138349
# Fasteners      0.082028
# Envelopes      0.080315
# Accessories    0.078452
# Supplies       0.076842
# Paper          0.074891
# Art            0.074874
# Storage        0.074704
# Labels         0.068681
# Name: Discount, dtype: float64

# %%
highest_discount_subcategory.plot(
    kind="barh",
    figsize=(10,6),
    title="Average Discount by Sub-Category"
)
# Out:
# <Axes: title={'center': 'Average Discount by Sub-Category'}, ylabel='Sub-Category'>

# %% [markdown]
# ### Customer Analysis
# Business Purpose<br>
# <br>
# Customer Analysis helps answer:<br>
# <br>
# Who are your best customers?<br>
# Who generates the most profit?<br>
# Which customers purchase repeatedly?<br>
# How many unique customers does the business have?<br>

# %%
top_customers = (
    sales_df.groupby("Customer Name")["Sales"]
            .sum()
            .sort_values(ascending=False)
            .head(10)
)

print(top_customers)
# Out:
# Customer Name
# Sean Miller           25043.050
# Tamara Chand          19052.218
# Raymond Buch          15117.339
# Tom Ashbrook          14595.620
# Adrian Barton         14473.571
# Ken Lonsdale          14175.229
# Sanjit Chand          14142.334
# Hunter Lopez          12873.298
# Sanjit Engle          12209.438
# Christopher Conant    12129.072
# Name: Sales, dtype: float64

# %%
top_customers.plot(
    kind="barh",
    figsize=(10,6),
    title="Top 10 Customers by Sales"
)
# Out:
# <Axes: title={'center': 'Top 10 Customers by Sales'}, ylabel='Customer Name'>

# %%
top_profit_customers = (
    sales_df.groupby("Customer Name")["Profit"]
            .sum()
            .sort_values(ascending=False)
            .head(10)
)

print(top_profit_customers)
# Out:
# Customer Name
# Tamara Chand            8981.3239
# Raymond Buch            6976.0959
# Sanjit Chand            5757.4119
# Hunter Lopez            5622.4292
# Adrian Barton           5444.8055
# Tom Ashbrook            4703.7883
# Christopher Martinez    3899.8904
# Keith Dawkins           3038.6254
# Andy Reiter             2884.6208
# Daniel Raglin           2869.0760
# Name: Profit, dtype: float64

# %%
top_profit_customers.plot(
    kind="barh",
    figsize=(10,6),
    title="Top 10 Customers by Profit"
)
# Out:
# <Axes: title={'center': 'Top 10 Customers by Profit'}, ylabel='Customer Name'>

# %%
repeat_customers = (
    sales_df.groupby("Customer Name")["Order ID"]
            .nunique()
            .sort_values(ascending=False)
            .head(10)
)

print(repeat_customers)
# Out:
# Customer Name
# Emily Phan             17
# Sally Hughsby          13
# Noel Staavos           13
# Patrick Gardner        13
# Zuschuss Carroll       13
# Joel Eaton             13
# Erin Ashbrook          13
# Chloris Kastensmidt    13
# Suzanne McNair         12
# Rick Bensley           12
# Name: Order ID, dtype: int64

# %%
unique_customers = sales_df["Customer ID"].nunique()

print(f"Number of Unique Customers : {unique_customers}")
# Out:
# Number of Unique Customers : 793

# %%
repeat_customers.plot(
    kind="barh",
    figsize=(10,6),
    title="Top 10 Repeat Customers"
)
# Out:
# <Axes: title={'center': 'Top 10 Repeat Customers'}, ylabel='Customer Name'>

# %% [markdown]
# ### Segment Analysis
# <br>
# dataset contains three customer segments:<br>
# <br>
# Consumer<br>
# Corporate<br>
# Home Office<br>

# %%
segment_sales = (
    sales_df.groupby("Segment")["Sales"]
            .sum()
            .sort_values(ascending=False)
)

print(segment_sales)
# Out:
# Segment
# Consumer       1.161401e+06
# Corporate      7.061464e+05
# Home Office    4.296531e+05
# Name: Sales, dtype: float64

# %%
segment_sales.plot(
    kind="bar",
    figsize=(7,5),
    title="Sales by Segment"
)
# Out:
# <Axes: title={'center': 'Sales by Segment'}, xlabel='Segment'>

# %%
segment_profit = (
    sales_df.groupby("Segment")["Profit"]
            .sum()
            .sort_values(ascending=False)
)

print(segment_profit)
# Out:
# Segment
# Consumer       134119.2092
# Corporate       91979.1340
# Home Office     60298.6785
# Name: Profit, dtype: float64

# %%
segment_profit.plot(
    kind="bar",
    figsize=(7,5),
    title="Profit by Segment"
)
# Out:
# <Axes: title={'center': 'Profit by Segment'}, xlabel='Segment'>

# %%
segment_quantity = (
    sales_df.groupby("Segment")["Quantity"]
            .sum()
            .sort_values(ascending=False)
)

print(segment_quantity)
# Out:
# Segment
# Consumer       19521
# Corporate      11608
# Home Office     6744
# Name: Quantity, dtype: int64

# %%
segment_quantity.plot(
    kind="bar",
    figsize=(7,5),
    title="Quantity by Segment"
)
# Out:
# <Axes: title={'center': 'Quantity by Segment'}, xlabel='Segment'>

# %% [markdown]
# ### Regional Analysis
# Business Purpose
# <br>
# Regional Analysis helps answer:<br>
#
# Which region generates the highest sales?<br>
# Which region earns the highest profit?<br>
# Which region sells the most products?<br>

# %%
region_sales = (
    sales_df.groupby("Region")["Sales"]
            .sum()
            .sort_values(ascending=False)
)

print(region_sales)
# Out:
# Region
# West       725457.8245
# East       678781.2400
# Central    501239.8908
# South      391721.9050
# Name: Sales, dtype: float64

# %%
region_sales.plot(
    kind="bar",
    figsize=(7,5),
    title="Sales by Region"
)
# Out:
# <Axes: title={'center': 'Sales by Region'}, xlabel='Region'>

# %%
region_profit = (
    sales_df.groupby("Region")["Profit"]
            .sum()
            .sort_values(ascending=False)
)

print(region_profit)
# Out:
# Region
# West       108418.4489
# East        91522.7800
# South       46749.4303
# Central     39706.3625
# Name: Profit, dtype: float64

# %%
region_profit.plot(
    kind="bar",
    figsize=(7,5),
    title="Profit by Region"
)
# Out:
# <Axes: title={'center': 'Profit by Region'}, xlabel='Region'>

# %%
region_quantity = (
    sales_df.groupby("Region")["Quantity"]
            .sum()
            .sort_values(ascending=False)
)

print(region_quantity)
# Out:
# Region
# West       12266
# East       10618
# Central     8780
# South       6209
# Name: Quantity, dtype: int64

# %%
region_quantity.plot(
    kind="bar",
    figsize=(7,5),
    title="Quantity Sold by Region"
)
# Out:
# <Axes: title={'center': 'Quantity Sold by Region'}, xlabel='Region'>

# %%
print(region_sales.head(1))
# Out:
# Region
# West    725457.8245
# Name: Sales, dtype: float64

# %%
print(region_profit.head(1))
# Out:
# Region
# West    108418.4489
# Name: Profit, dtype: float64

# %%
print(region_sales.tail(1))
# Out:
# Region
# South    391721.905
# Name: Sales, dtype: float64

# %% [markdown]
# ### State Analysis
# Business Purpose
#
# State Analysis helps identify:
#
# * Top-performing states
# * Poor-performing states
# * Highest profit state
# * Highest loss state

# %%
top_states = (
    sales_df.groupby("State")["Sales"]
            .sum()
            .sort_values(ascending=False)
            .head(10)
)

print(top_states)
# Out:
# State
# California      457687.6315
# New York        310876.2710
# Texas           170188.0458
# Washington      138641.2700
# Pennsylvania    116511.9140
# Florida          89473.7080
# Illinois         80166.1010
# Ohio             78258.1360
# Michigan         76269.6140
# Virginia         70636.7200
# Name: Sales, dtype: float64

# %%
top_states.plot(
    kind="barh",
    figsize=(10,6),
    title="Top 10 States by Sales"
)
# Out:
# <Axes: title={'center': 'Top 10 States by Sales'}, ylabel='State'>

# %%
bottom_states = (
    sales_df.groupby("State")["Sales"]
            .sum()
            .sort_values()
            .head(10)
)

print(bottom_states)
# Out:
# State
# North Dakota             919.910
# West Virginia           1209.824
# Maine                   1270.530
# South Dakota            1315.560
# Wyoming                 1603.136
# District of Columbia    2865.020
# Kansas                  2914.310
# Idaho                   4382.486
# Iowa                    4579.760
# New Mexico              4783.522
# Name: Sales, dtype: float64

# %%
bottom_states.plot(
    kind="barh",
    figsize=(10,6),
    title="Bottom 10 States by Sales"
)
# Out:
# <Axes: title={'center': 'Bottom 10 States by Sales'}, ylabel='State'>

# %%
state_profit = (
    sales_df.groupby("State")["Profit"]
            .sum()
            .sort_values(ascending=False)
)

print(state_profit.head(1))
# Out:
# State
# California    76381.3871
# Name: Profit, dtype: float64

# %%
print(state_profit.tail(1))
# Out:
# State
# Texas   -25729.3563
# Name: Profit, dtype: float64

# %%
state_profit.sort_values().plot(
    kind="barh",
    figsize=(12,10),
    title="Profit by State",
)
# Out:
# <Axes: title={'center': 'Profit by State'}, ylabel='State'>
